# %%
import pandas as pd

# %%
df = pd.read_csv('ocorrencia_2010_2020.csv', sep =";", parse_dates=['ocorrencia_dia'], dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia2 ocorrencia_classificacao  \
# 0              40211               40211                INCIDENTE
# 1              40349               40349                INCIDENTE
# 2              40351               40351                INCIDENTE
# 3              39527               39527                 ACIDENTE
# 4              40324               40324                INCIDENTE
#
#     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo ocorrencia_dia  \
# 0      RIO DE JANEIRO            RJ                 ****     2010-01-03
# 1               BELÉM            PA                 SBBE     2010-01-03
# 2      RIO DE JANEIRO            RJ                 SBRJ     2010-01-03
# 3  LUCAS DO RIO VERDE            MT                 ****     2010-01-04
# 4             PELOTAS            RS                 SBPK     2010-01-05
#
#   ocorrencia_hora  total_recomendacoes
# 0        12:00:00                    0
# 1        11:05:00                    0
# 2        03:00:00                    0
# 3        17:30:00                    0
# 4        19:25:00                    0

# %%
df.loc[1,'ocorrencia_cidade']
# Out:
# 'BELÉM'

# %%
df.loc[1]
# Out:
# codigo_ocorrencia                         40349
# codigo_ocorrencia2                        40349
# ocorrencia_classificacao              INCIDENTE
# ocorrencia_cidade                         BELÉM
# ocorrencia_uf                                PA
# ocorrencia_aerodromo                       SBBE
# ocorrencia_dia              2010-01-03 00:00:00
# ocorrencia_hora                        11:05:00
# total_recomendacoes                           0
# Name: 1, dtype: object

# %%
#vendo se é um valor único
df.codigo_ocorrencia.is_unique
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)

# %%
#df.head(10)

# %%
#ocorrencia de todos de SP
df.loc[df.ocorrencia_uf=='SP', ['ocorrencia_classificacao']]
# Out:
#                   ocorrencia_classificacao
# codigo_ocorrencia
# 40069                             ACIDENTE
# 39809                            INCIDENTE
# 39828                            INCIDENTE
# 39847                            INCIDENTE
# 39768                            INCIDENTE
# ...                                    ...
# 79739                      INCIDENTE GRAVE
# 79705                      INCIDENTE GRAVE
# 79718                      INCIDENTE GRAVE
# 79800                            INCIDENTE
# 79804                            INCIDENTE
#
# [1373 rows x 1 columns]

# %%
# Resetar indice:
#df.reset_index(drop=True, inplace=True)

# %%
# Alterando valores de uma celula da linha
#df.loc[0,'ocorrencia_aerodromo'] = ''

# %%
#alterando uma linha só
#df.loc(1)

# %%
#usando filtros -> Alterando a classificação de todos de SP para grave

df.loc[df.ocorrencia_uf == 'SP', ['ocorrencia_classificacao']=='GRAVE']

# %% [raw]
# correncia_aerodromo
#
# ###!
# ####
# ***
# ****
#
# ocorrencia_uf
# **
#
# Ocorrencia_hora
# NULL

# %%
df.loc[df.ocorrencia_aerodromo=='****',['ocorrencia_aerodromo']] =pd.NA

# %%
df.head()
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 <NA>
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 <NA>
# 40324                         PELOTAS            RS                 SBPK
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 40211                 2010-01-03        12:00:00                    0
# 40349                 2010-01-03        11:05:00                    0
# 40351                 2010-01-03        03:00:00                    0
# 39527                 2010-01-04        17:30:00                    0
# 40324                 2010-01-05        19:25:00                    0

# %%
df.replace(['**','###!', '####', '***', '****', 'NULL'], pd.NA, inplace=True)

# %%
df.head(20)
# Out:
#                    codigo_ocorrencia2 ocorrencia_classificacao  \
# codigo_ocorrencia
# 40211                           40211                INCIDENTE
# 40349                           40349                INCIDENTE
# 40351                           40351                INCIDENTE
# 39527                           39527                 ACIDENTE
# 40324                           40324                INCIDENTE
# 39807                           39807                INCIDENTE
# 40215                           40215                INCIDENTE
# 39707                           39707          INCIDENTE GRAVE
# 39156                           39156          INCIDENTE GRAVE
# 39711                           39711          INCIDENTE GRAVE
# 39789                           39789                INCIDENTE
# 40069                           40069                 ACIDENTE
# 40414                           40414                INCIDENTE
# 39507                           39507                 ACIDENTE
# 40107                           40107                 ACIDENTE
# 39315                           39315                 ACIDENTE
# 39809                           39809                INCIDENTE
# 39810                           39810                INCIDENTE
# 39828                           39828                INCIDENTE
# 44575                           44575                INCIDENTE
#
#                     ocorrencia_cidade ocorrencia_uf ocorrencia_aerodromo  \
# codigo_ocorrencia
# 40211                  RIO DE JANEIRO            RJ                 <NA>
# 40349                           BELÉM            PA                 SBBE
# 40351                  RIO DE JANEIRO            RJ                 SBRJ
# 39527              LUCAS DO RIO VERDE            MT                 <NA>
# 40324                         PELOTAS            RS                 SBPK
# 39807                        SALVADOR            BA                 <NA>
# 40215                           COARI            AM                 SBUY
# 39707                        CANUTAMA            AM                 <NA>
# 39156                        CASCAVEL            PR                 SBCA
# 39711                   PARÁ DE MINAS            MG                 <NA>
# 39789                SÃO PEDRO DO SUL            RS                 <NA>
# 40069                       SÃO PAULO            SP                 SBMT
# 40414                        BRASÍLIA            DF                 SBBR
# 39507              PRIMAVERA DO LESTE            MT                 <NA>
# 40107                          GURUPÁ            PA                 SNGU
# 39315                        CANUTAMA            AM                 <NA>
# 39809                       SÃO PAULO            SP                 <NA>
# 39810                        SALVADOR            BA                 <NA>
# 39828                          SANTOS            SP                 <NA>
# 44575                  RIO DE JANEIRO            RJ                 SBGL
#
#                   ocorrencia_dia ocorrencia_hora  total_recomendacoes
# codigo_ocorrencia
# 40211                 2010-01-03        12:00:00                    0
# 40349                 2010-01-03        11:05:00                    0
# 40351                 2010-01-03        03:00:00                    0
# 39527                 2010-01-04        17:30:00                    0
# 40324                 2010-01-05        19:25:00                    0
# 39807                 2010-01-06        17:53:00                    0
# 40215                 2010-01-07        18:40:00                    0
# 39707                 2010-01-09        12:30:00                    3
# 39156                 2010-01-10        23:15:00                    2
# 39711                 2010-01-10        20:00:00                    0
# 39789                 2010-01-10        21:30:00                    0
# 40069                 2010-01-10        14:50:00                    8
# 40414                 2010-01-10        03:00:00                    0
# 39507                 2010-01-11        17:00:00                    2
# 40107                 2010-01-12        14:30:00                    0
# 39315                 2010-01-15        21:22:00                    0
# 39809                 2010-01-15        15:00:00                    0
# 39810                 2010-01-15        18:23:00                    0
# 39828                 2010-01-15        17:45:00                    0
# 44575                 2010-01-17        12:27:00                    0

# %%
df.isnull().sum()
# Out:
# codigo_ocorrencia2             0
# ocorrencia_classificacao       0
# ocorrencia_cidade              0
# ocorrencia_uf                  1
# ocorrencia_aerodromo        2199
# ocorrencia_dia                 0
# ocorrencia_hora                1
# total_recomendacoes            0
# dtype: int64

# %%
# criando uma nova coluna
#df['total_recomendacoes_bk'] = df.total_recomendacoes
